# %% [markdown]
# # Field Significance
#
# *last updated March 30, 2026 by Kevin Anchukaitis to improve code clarity and use Scipy for the binomial distribution*
#
# The topic of field significance is broadly concerned with determining if the results of a correlation between a time series and the set of many time series that comprise a field of space-time data is significant.  While there are well-known parametric tests for assessing statistical significance and evaluating a null hypothesis, field correlations present at least two challenges to a conventional interpretation of a small _p-value_ as indicative of a meaningful relationship.  These include:
#
# * a multiple comparison problem -- we are conducting a large number of correlation analyses, from which we would expect a certain proportion would meet any given significance threshold simply by chance, and effect we need to account for
# * a spatial autocorrelation problem -- most of our spatial data will be dependent (correlated with one another as a function of space), with the implication that there are many fewer degrees of (spatial) freedom in our field correlation result than there are grid points and this must be accounted for
#
# An excellent overall discussion of field significance is available in Chapter 13 of the book _[Statistical Methods for Climate Scientists](https://www.cambridge.org/us/universitypress/subjects/earth-and-environmental-science/climatology-and-climate-change/statistical-methods-climate-scientists?format=HB&isbn=9781108472418)_ by Timothy DelSole and [Michael Tippett](https://github.com/mktippett).  If you have library access, you may be able to find the chapter in PDF form [here](https://www.cambridge.org/core/books/statistical-methods-for-climate-scientists/field-significance/B4107B7D3330991718C5A0828679D03B).
#
# Here we're going to look at 3 different tests, all of which are featured in your reading for this section of the course.  We'll first briefly look at the 'binomial test' from [Livezey and Chen (1983)](https://doi.org/10.1175/1520-0493(1983)111%3C0046:SFSAID%3E2.0.CO;2) before moving onto their Monte Carlo approach to field significance.  Finally, we'll look at the method of [False Discovery Rate](https://rss.onlinelibrary.wiley.com/doi/10.1111/j.2517-6161.1995.tb02031.x) (FDR), specifically as described in a climate science context by [Ventura et al. (2004)](https://doi.org/10.1175/3199.1).
#
# Let's get started.

# %%
import math
import numpy as np
import scipy as sp
import pandas as pd
import xarray as xr
import matplotlib as mpl
import matplotlib.pyplot as plt

# nicely render figures in the notebook 
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Cartopy gives a lot of warnings when downloading map data, which we'll suppress
import warnings
warnings.filterwarnings("ignore") 

# you can omit the line below if you'd like, but I really don't like the default fonts in Python, so I switch to Helvetica
plt.rcParams['font.family'] = 'Helvetica'

# import cartopy 
import cartopy # base Cartopy
import cartopy.crs as ccrs # shortcut to the coordinate reference system
import cartopy.feature as cfeature # add map features

# %% [markdown]
# ## Binomial Test Example
#
# Livezey and Chen (1983) point out that because we are doing a potentially large but finite number of comparisons (between a time series and a set of other time series), we can calculate the probability of falsely rejecting the null -- a Type 1 error -- using the binomial distribution.  In simple terms, we might ask ’how many individual significance tests must be passed (that is, significant at $p<0.05$) when trying $N$ experiments to ensure these don't indicate a meaningful field relationship by accident at a confidence level of $p=0.05$?'  However, a problem with using the binomial test will quickly become apparent, because our comparisons (and the test for a null hypothesis for each) are not _independent_ at all!  Spatial autocorrelation means that as we conduct mulitple correlations between a time series and the time series that make up a field, the spatial dependence violates the assumption of independence of each individual test from the others that is assumed in this test.
#
# Nevertheless, this provide a useful first place to start to think about the concept of _field significance_.  In the Livezey and Chen approaches, we are not evaluating the significance of any individual point in our field correlation, but rather we are evaluating whether the number of significant values as a whole might arise by chance.  Or, to put it still another way, we are evaluating the significance of our correlation map as a whole, not at any individual location.
#
# Let's repeat the example shown in Section 2 and Figure 2 of [Livezey and Chen (1983)](https://doi.org/10.1175/1520-0493(1983)111%3C0046:SFSAID%3E2.0.CO;2).  We will conduct their binomial test for N individual tests of correlation and an _a priori_ significance level of $\alpha=0.05$.  The binomial test allows us to calculate the probability of observing $x$ number of successful significance tests as a function of the number of *independent* tests and the alpha level:
#
# $$
# Pr\{x\} = \frac{N!}{x!(N-x)!} \alpha^x (1-\alpha)^{N-x}
# $$
#
# In a previous version of this notebook, I coded the binominal test up just based on the equation above and a loop.   But Scipy actually has this as a set of methods for the binomial distribution, so we can use those.  Specifically, `scipy.stats.binom.pmf` is the probability mass function from the binomial distribution, which is the probability that the random variable will take a given value, and `scipy.stats.binom.sf` is the survival function, or `1-cdf` for a given value in the distribution.
#
# Let's see what this looks like by reproducing what Livezey and Chen (1983) did in their paper:

# %%
# specify the number of tests and an a priori alpha value
N = 30 # the number of independent tests (e.g. correlations) 
alpha = 0.05 # the a priori significance level

# binomial probability mass function, or the probability of observing exactly x passed tests out of N
Pr = sp.stats.binom.pmf(np.arange(N + 1), N, alpha) 

# cumulative probability of greater than and equal to that many events (the survival function)
P = sp.stats.binom.sf(np.arange(N + 1) - 1, N, alpha)

# Plot the results of the test
plt.figure()
plt.plot(np.arange(0, N + 1), Pr, 'kx-', label='Probability of exact number of passed tests (Pr from pmf)')
plt.plot(np.arange(0, N + 1), P, 'ko--', markerfacecolor="None", label='Cumulative probability (P from sf)') # label='P(M >= M_0)
plt.plot([0, 30], [0.05, 0.05], 'r--', label="Significance threshold (alpha)")
plt.xlabel('Number of passed tests')
plt.ylabel('PROBABILITY')
plt.ylim((0,1.1))
plt.xlim(-1,21) # mimic the Livezey and Chen plot
plt.legend(loc='upper right')

# %% [markdown]
# You can compare the above plot to Figure 2 in [Livezey and Chen (1983)](https://doi.org/10.1175/1520-0493(1983)111%3C0046:SFSAID%3E2.0.CO;2).  The binomial test suggests that for this simple system, you need to pass at least 5 significance tests out of the 30 you conduct in total to be confident -- at the given significance level -- that this result was unlikely to be observed simply by chance.  However, we already know that this is not appropriate for most spatial field correlations, because this only holds if those 30 tests are truly independent from one another.
#
# Incidently, why does the probability of observing exactly *x* significant correlation tests rise between x=0 passed tests and x=1 passed test, and then fall again?  You can think of this as there being only 1 way to observe 0 significant correlations (e.g. all 30 correlations fail to be significant) vs. there being 30 different ways to observe 1 significant correlation out of 30 (the shape of the probability mass function is therefore capturing the trade off between the number of possible combinations vs. the probability of success). Probability is weird and will mess with your brain, yo.
#
# OK, so what else might we do?  One thing we've hopefully grown accustomed to in this class are empirical and non-parametric approaches, including Monte Carlo procedures (e.g. like Rule N).  If the problem with binomial test is that the assumption of independence is violated, how might we conduct a test which accounts for the fact that our field of time series are (spatially) dependent in some way?  This leads us to the following approach to field correlation using field randomization and Monte Carlo methods.

# %% [markdown]
# ## Random field significance tests
#
# As Livezey and Chen point out:
#
# > Large cross-correlations in the field reduce the so-called 'degrees of freedom' of the field in the same way that large lag autocorrelation reduce the number of effective samples in a time series. Instead of a set of N individual realizations, such a field should be viewed as $n<N$ independent clusters of closely related realizations.
#
# In theory, then, if we could determine the 'true' degrees of freedom and the effective sample size, the equation and approach we used above might still be used even in the case of spatial autocorrelation in the field by modifying the $N$ appropriately (and as we will discuss in lecture for the case of temporal autocorrelation).  But in most *real* fields, this is a non-trivial calculation.  Whereas we have relatively well-known methods for estimating lagged autocorrelation and therefore temporal autocorrelation, in the complex spatial structure of a field, it is less clear how to assign a single number to the reduction in the effective sample size $n$ of individual tests that comes from spatial autocorrelation.
#
# Livezey and Chen also recognize this, and later in the same paper write:
#
# > ... when estimates of $n$ are unavailable or when experimental results fall within their range, the only recourse to evaluate field significance is a Monte Carlo simulation. This is because multivariate techniques cannot be applied to large numbers of relatively short geophysical time series ... There are a number of considerations in the design of Monte Carlo simulations.  First, the random component must be introduced in such a way as to retain the interdependence whose effects need to be evaluated.  Second, probabilities of chance outcomes under the null hypothesis in the actual experiment must be matched in the Monte Carlo simulation.  Third, enough simulations need to be performed to estimate the probability accurately
#
# The first of these considerations will now be the one of most interest.  Simply put, how do we sufficiently 'simulate' the features of the field but still at the same time simulate our null condition?  There are potentially several answers to this, but below we'll see an approach that iteratively randomizes the temporal _order_ of the field while keeping the spatial ordering.  This preserves the spatial autocorrelation but destroys (or at least damages) the real temporal match between our time series and the field (alternatively, one could simply randomize the single time series itself, which should accomplish the same thing! But, I want you to see the more complicated approach of randomizing the field, in case it should prove useful).
#
# Let's get our old friend the SOI and the 700mb height field to use for this example:

# %%
# read in the soi index as a DataSet, but don't automatically decode the (monthly) time units
soi_ds = xr.open_dataset("soi.nc", mask_and_scale=True, decode_times=False)

# because 'months since' is an ambiguous time unit, we build the time coordinate manually.
new_time = pd.date_range(start='1866-01', periods=len(soi_ds["time"]), freq='MS') # pd.date_range with freq='MS' gives first-of-month dates

# assign_coords replaces the time coordinate while we extract the DataArray
soi = soi_ds["SOI"].assign_coords(time=new_time)

# calculate the 3-month rolling mean, using min_periods=3 ensures incomplete windows are NaN
soi_rolling = soi.rolling(time=3, min_periods=3).mean()

# select the February to get the 3-month average ending in February (DJF)
djf_soi = soi_rolling[soi_rolling.time.dt.month == 2]

# %% [markdown]
# Now the 700mb geopotential heights:

# %%
# read in the height field as a DataSet - allow xrray to decode the time since it is in units of days
hgt = xr.open_dataset("hgt.700mb.mon.mean.nc", mask_and_scale=True)
hgt = hgt["hgt"] # pull out just the variable we want

# calculate the 3-month rolling mean
hgt_rolling = hgt.rolling(time=3, min_periods=3).mean()

# select the February to get the 3-month average ending in February (DJF)
djf_hgt = hgt_rolling[hgt_rolling.time.dt.month == 2]
djf_hgt = djf_hgt.squeeze(drop=True) # squeeze out and drop the singleton 'level' dimension

# %% [markdown]
# Once again, we can use `xr.align` with the `join="inner"` to put the two variables on the same time dimension:

# %%
djf_hgt, djf_soi = xr.align(djf_hgt,djf_soi,join="inner") # hgt and sst now have the same time dimension

# %% [markdown]
# And then we can do our field correlation.  We can get the correlation between the two DataArrays using `xr.corr`, but now we also want the significance of each of the field correlation coefficients, which we'll calculate directly (because it is fast):

# %%
# correlation values only from this
fieldCorrelation = xr.corr(djf_soi,djf_hgt, dim="time")

# so, we'll calculate the p-values directly using r values above and the corresponding t-distribution
t = -abs(fieldCorrelation.values)*np.sqrt((len(djf_soi.time)-2)/(1-np.square(fieldCorrelation.values))) # t values
pvalue = sp.stats.t.cdf(t, len(djf_soi.time) - 2) * 2 # we multiply by 2 for two-sided test from the t-distribution
sig = xr.DataArray(data=pvalue, dims=["lat","lon"], coords=[fieldCorrelation.lat, fieldCorrelation.lon])

# %% [markdown]
# Now we'll plot both the correlation coefficients and indicate the significant locations:

# %%
# defines areas with non-sigificant coefficients
sig_area1   = np.where(sig < 0.05) # this is a tuple! 
lons, lats = np.meshgrid(fieldCorrelation.lon,fieldCorrelation.lat)

# plot the field correlations
fig, (ax1) = plt.subplots(clear=True,nrows=1,ncols=1,subplot_kw={'projection': ccrs.Robinson(central_longitude=180)})

# specifying the levels gives us more control on the map
levels = np.linspace(-1, 1, 31)

fx1 = ax1.contourf(djf_hgt.lon,djf_hgt.lat,fieldCorrelation,levels=levels, cmap='Spectral_r',add_colorbar=False, transform=ccrs.PlateCarree())
ax1.coastlines(color="black")  # we can pass arguments to .coastlines function
ax1.set_title('r(DJF SOI,DJF 700mb GPH)', fontsize=12)
cb1 = plt.colorbar(fx1,  orientation='horizontal',location='bottom',shrink=0.9,pad=0.05,ticks=[-1, -0.75, -0.50, -0.25, 0.0, 0.25, 0.50, 0.75, 1])
ax1.scatter(lons[sig_area1], lats[sig_area1], marker = '.', s = 0.1, c = 'k', alpha = 0.4, transform = ccrs.PlateCarree())
cb1.set_label('Correlation', fontsize=12)

# %% [markdown]
# How many locally significant values are there?

# %%
numberSignificant = (sig<0.05).sum()
numberSignificant.values
# Out:
# array(34292)

# %% [markdown]
# That's a lot! For a 1x1 degree field, with 64,800 latitude and longitude points, over half of the locations in the field have a correlation with SOI that is locally significant at *p<0.05*.
#
# But remember what we're scared of (besides clowns): our concern is that *by chance* our time series might be similar to one or more of those 64,800 time series that make up the field, and that because many of *those* series are similar to one another, we could see spatial patterns of significant correlation that still arise just by chance.

# %%
iterations = 100 # about 18 seconds for 100
randomNumberSignificant = np.empty(iterations)

rng = np.random.default_rng()

# initialize here to None so we can detect if none of the iterations are in the target range
sig_art = None
fieldCorrelation_art = None

for i in range(iterations):
    random_array = djf_hgt.isel(time=rng.choice(djf_hgt.time.size, djf_hgt.time.size, replace=False)) 
    random_array["time"] = djf_hgt.time
    fieldCorrelation0 = xr.corr(djf_soi, random_array, dim="time")
    
    # calculate the p-values directly using r values and the t-distribution
    t0 = -abs(fieldCorrelation0.values)*np.sqrt((len(djf_soi.time)-2)/(1-np.square(fieldCorrelation0.values)))
    pvalue0 = sp.stats.t.cdf(t0, len(djf_soi.time) - 2) * 2 # multiply by 2 for two-sided test
    randomNumberSignificant[i] = (pvalue0<0.05).sum()
    if randomNumberSignificant[i] < 10000 and randomNumberSignificant[i] > 5000:
        sig_art = xr.DataArray(data=pvalue0, dims=["lat","lon"], coords=[fieldCorrelation.lat, fieldCorrelation.lon])
        fieldCorrelation_art = fieldCorrelation0
        
fig, ax1 = plt.subplots()
ax1.hist(randomNumberSignificant)
ax1.axvline(numberSignificant, color="k", linestyle="--", label="Observed")
ax1.set_ylabel("FREQUENCY")
ax1.set_xlabel("NUMBER SIGNIFICANT")
ax1.text(numberSignificant, ax1.get_ylim()[1]/2, 'OBSERVED', verticalalignment="center", rotation=-90);

# %% [markdown]
# The code above saves one of the random field correlation patterns and significance if it exceed 5,000 locally significant values but is less than 10,000.  These will be patterns where there is likely to be a specific location on the globe with a cluster of significant points, the kind of remote yet coherent looking teleconnection pattern you might see in a paleoclimate paper.  We can plot these here:

# %%
if sig_art is None:
    print("No iteration produced between 5,000 and 10,000 significant points - catch this and skip the plot")
else:
    # define areas with significant coefficients in the random field
    sig_area_art = np.where(sig_art < 0.05) # this is a tuple! 
    lons, lats = np.meshgrid(fieldCorrelation.lon, fieldCorrelation.lat)

    # plot the field correlations
    fig, (ax1) = plt.subplots(clear=True, nrows=1, ncols=1, subplot_kw={'projection': ccrs.Robinson(central_longitude=180)})

    # specifying the levels gives us more control on the map
    levels = np.linspace(-1, 1, 31)

    fx1 = ax1.contourf(djf_hgt.lon, djf_hgt.lat, fieldCorrelation_art, levels=levels, cmap='Spectral_r', add_colorbar=False, transform=ccrs.PlateCarree())
    ax1.coastlines(color="black")
    ax1.set_title('RANDOM FIELD CORRELATION AND SIGNIFICANCE', fontsize=12)
    cb1 = plt.colorbar(fx1, orientation='horizontal', location='bottom', shrink=0.9, pad=0.05, ticks=[-1, -0.75, -0.50, -0.25, 0.0, 0.25, 0.50, 0.75, 1])
    ax1.scatter(lons[sig_area_art], lats[sig_area_art], marker='.', s=0.1, c='k', alpha=0.4, transform=ccrs.PlateCarree())
    cb1.set_label('Correlation', fontsize=12)

# %%
numberRandomSignificant = (sig_art<0.05).sum()
numberRandomSignificant.values
# Out:
# array(8176)

# %% [markdown]
# But we can see that in this example, the number of passed local significance tests for the real data in the true order (SOI vs. 700mb geopotential heights) is much higher than the number that comes from the randomization Monte Carlo test:

# %%
significance_level = ((randomNumberSignificant<numberSignificant.values).sum()/iterations)*100
significance_level # percent of time the number of significant values for the original order data is greater than with the randomized data
# Out:
# np.float64(100.0)

# %% [markdown]
# It is possible that shuffling the year order of the field is too 'liberal' in way (too east to pass the test), if in fact there is important temporal autocorrelation in the time series.  In this case, it might be better to either shift (randomly) the series in time or to do a block shuffling, for which a package [`xbootstrap`](https://pypi.org/project/xbootstrap/) appears to make this easier in xarray.

# %% [markdown]
# ## The False Discovery Rate

# %% [markdown]
# The field significance via Monte Carlo and temporal randomization is used quite frequently, but all it does is tell us whether the total number of locally significant points is greater than expected for some null.  It does not tell us, however, where the local significance might rise to a level where we should interpret the local correlation as meaningful.  As Ventura et al. (2004) note:
#
# > The method of Livezey and Chen (1983) detects field significance, with $p < 0.001$, but gives no indication about which particular locations are significant, even though this is of crucial interest. For that, we must test for a change at each location.
#
# In fact the methods from Livezey and Chen (1983) can return an significance level we elect to use, but this does address the central question about _where_ the local correlation significant might exceed what could occur by chance in our multiple comparison situation.
#
# Ventura et al. (2004) propose the use of the False Discovery Rate, originally described by [Benjamini and Hochberg 1995](https://doi.org/10.1111/j.2517-6161.1995.tb02031.x).
#
# For the first time in this course, we'll also import the [Pyleoclim](https://pyleoclim-util.readthedocs.io/en/latest/) package, which is designed specifically for the analysis of paleoclimate data.  It contains a function for the False Discovery Rate (FDR) test.  In fact, there are implementation of FDR in several Python packages, including ones we've already encountered.  But because the function in Pyleoclim arises specifically from Ventura et al. (2004) we'll use it here.

# %%
# !pip install pyleoclim
# Out:
# Collecting pyleoclim
#   Downloading pyleoclim-1.2.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pandas>=2.1.4 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (3.0.0)
# Collecting kneed>=0.7.0 (from pyleoclim)
#   Downloading kneed-0.8.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (0.14.6)
# Requirement already satisfied: seaborn>=0.13.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.24.2 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (1.8.0)
# Collecting pathos>=0.2.8 (from pyleoclim)
#   Downloading pathos-0.3.5-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm>=4.61.2 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (4.67.1)
# Collecting tftb>=0.1.3 (from pyleoclim)
#   Downloading tftb-0.2.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting wget>=3.2 (from pyleoclim)
#   Downloading wget-3.2.zip (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numba>=0.56 (from pyleoclim)
#   Downloading numba-0.64.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.9 kB)
# Collecting nitime>=0.9 (from pyleoclim)
#   Downloading nitime-0.12.1-cp311-abi3-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Collecting tabulate>=0.8.9 (from pyleoclim)
#   Downloading tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Collecting Unidecode>=1.1.1 (from pyleoclim)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cartopy>=0.22.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (0.25.0)
# Requirement already satisfied: pyyaml in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (4.14.3)
# Collecting scipy<1.16.0 (from pyleoclim)
#   Downloading scipy-1.15.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: requests in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyleoclim) (2.32.5)
# Collecting dill (from pyleoclim)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from scipy<1.16.0->pyleoclim) (2.4.1)
# Requirement already satisfied: matplotlib>=3.6 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from cartopy>=0.22.0->pyleoclim) (3.10.8)
# Requirement already satisfied: shapely>=2.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from cartopy>=0.22.0->pyleoclim) (2.1.2)
# Requirement already satisfied: packaging>=21 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from cartopy>=0.22.0->pyleoclim) (26.0)
# Requirement already satisfied: pyshp>=2.3 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from cartopy>=0.22.0->pyleoclim) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from cartopy>=0.22.0->pyleoclim) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (2.9.0.post0)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.56->pyleoclim)
#   Downloading llvmlite-0.46.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting ppft>=1.7.8 (from pathos>=0.2.8->pyleoclim)
#   Downloading ppft-1.7.8-py3-none-any.whl.metadata (12 kB)
# Collecting pox>=0.3.7 (from pathos>=0.2.8->pyleoclim)
#   Downloading pox-0.3.7-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.19 (from pathos>=0.2.8->pyleoclim)
#   Downloading multiprocess-0.70.19-py311-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: certifi in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from pyproj>=3.3.1->cartopy>=0.22.0->pyleoclim) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy>=0.22.0->pyleoclim) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from scikit-learn>=0.24.2->pyleoclim) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from scikit-learn>=0.24.2->pyleoclim) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from statsmodels>=0.13.2->pyleoclim) (1.0.2)
# Collecting numpy<2.5,>=1.23.5 (from scipy<1.16.0->pyleoclim)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from beautifulsoup4->pyleoclim) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from beautifulsoup4->pyleoclim) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from requests->pyleoclim) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from requests->pyleoclim) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kja/anaconda3/envs/geog696c_python311/lib/python3.11/site-packages (from requests->pyleoclim) (2.6.3)
# Downloading pyleoclim-1.2.1-py3-none-any.whl (644 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 443.0 kB/s  0:00:01eta 0:00:01
# Downloading scipy-1.15.3-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 988.5 kB/s  0:00:22m0:00:0100:03
# Downloading kneed-0.8.6-py3-none-any.whl (10 kB)
# Downloading nitime-0.12.1-cp311-abi3-macosx_11_0_arm64.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 8.6 MB/s  0:00:00 eta 0:00:01
# Downloading numba-0.64.0-cp311-cp311-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 9.8 MB/s  0:00:00m eta 0:00:01
# Downloading llvmlite-0.46.0-cp311-cp311-macosx_11_0_arm64.whl (37.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 11.9 MB/s  0:00:03m0:00:0100:01
# Downloading pathos-0.3.5-py3-none-any.whl (82 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading multiprocess-0.70.19-py311-none-any.whl (144 kB)
# Downloading pox-0.3.7-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.8-py3-none-any.whl (56 kB)
# Downloading tabulate-0.10.0-py3-none-any.whl (39 kB)
# Downloading tftb-0.2.0-py3-none-any.whl (54 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (pyproject.toml) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9685 sha256=d716c025f98c9cdb7760928c01fd9c2b805fec5ec3c1d707e4b83b7b42be39aa
#   Stored in directory: /Users/kja/Library/Caches/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget, Unidecode, tabulate, ppft, pox, numpy, llvmlite, dill, scipy, numba, multiprocess, pathos, kneed, tftb, nitime, pyleoclim
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [pox]
#     Found existing installation: numpy 2.4.1━━━━━━━━━━━━━━━━━━  4/16 [pox]
#     Uninstalling numpy-2.4.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [pox]
#       Successfully uninstalled numpy-2.4.1━━━━━━━━━━━━━━━━━━━━  4/16 [pox]
#   Attempting uninstall: scipy╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [dill]ite]
#     Found existing installation: scipy 1.17.0━━━━━━━━━━━━━━━━━  7/16 [dill]
#     Uninstalling scipy-1.17.0:╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [dill]
#       Successfully uninstalled scipy-1.17.0━━━━━━━━━━━━━━━━━━━  7/16 [dill]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [pyleoclim]16 [pyleoclim]
# Successfully installed Unidecode-1.4.0 dill-0.4.1 kneed-0.8.6 llvmlite-0.46.0 multiprocess-0.70.19 nitime-0.12.1 numba-0.64.0 numpy-1.26.4 pathos-0.3.5 pox-0.3.7 ppft-1.7.8 pyleoclim-1.2.1 scipy-1.15.3 tabulate-0.10.0 tftb-0.2.0 wget-3.2

# %%
# get the Pyleoclim package
import pyleoclim

# %% [markdown]
# `pyleoclim.utils.correlation.fdr` accepts a list or array of p-values, so we'll need to use e.g. `.ravel` to turn our 2-dimensional (longitude and latitude grid) set of p-values into a strung-out array.  We then pass that strung-out array to the function, which returns an index of the locations in the array with significant p-values at the q-level (here using the default 0.05).

# %%
pvals = pvalue.ravel()
fdr_idx = pyleoclim.utils.correlation.fdr(pvals,qlevel=0.05, method='original')
fdr_threshold = pvals[fdr_idx].max() # the maximum p-value that survived the FDR is our new threshold
sig_area2   = np.where(sig <= fdr_threshold) # this is a tuple!

# %%
m = (np.arange(1,len(pvals)+1)/len(pvals))
fdr_line = m * 0.05

fig, ax1 = plt.subplots()
plt.plot(m,np.sort(pvals),'k-',label='SORTED P-VALUES')
plt.plot(m,fdr_line,color="r",linestyle="--",label='FDR THRESHOLD')
plt.plot([np.min(m),np.max(m)],[0.05,0.05],color='red',linestyle=":",label="TRADITIONAL THRESHOLD")
plt.xlabel('P-VALUE FRACTIONAL RANK')
plt.ylabel('P-VALUE')
plt.legend()
plt.xlim(0,0.65)
plt.ylim(0,0.09)
# Out:
# (0.0, 0.09)

# %%
numberSignificantFDR = (sig<fdr_threshold).sum()
numberSignificantFDR.values
# Out:
# array(30777)

# %%
# plot the field correlations
fig, (ax1,ax2) = plt.subplots(clear=True,nrows=2,ncols=1,subplot_kw={'projection': ccrs.Robinson(central_longitude=180)})

# specifying the levels gives us more control on the map
levels = np.linspace(-1, 1, 31)

fx1 = ax1.contourf(djf_hgt.lon,djf_hgt.lat,fieldCorrelation,levels=levels, cmap='Spectral_r',add_colorbar=False, transform=ccrs.PlateCarree())
ax1.coastlines(color="black")  # we can pass arguments to .coastlines function
ax1.set_title('r(DJF SOI,DJF 700mb GPH) P < 0.05', fontsize=12)
cb1 = plt.colorbar(fx1,  orientation='vertical',location='left',shrink=0.9,pad=0.05,ticks=[-1, -0.75, -0.50, -0.25, 0.0, 0.25, 0.50, 0.75, 1])
ax1.scatter(lons[sig_area1], lats[sig_area1], marker = '.', s = 0.1, c = 'k', alpha = 0.4, transform = ccrs.PlateCarree())
cb1.set_label('Correlation', fontsize=12) 

fx2 = ax2.contourf(djf_hgt.lon,djf_hgt.lat,fieldCorrelation,levels=levels, cmap='Spectral_r',add_colorbar=False, transform=ccrs.PlateCarree())
ax2.coastlines(color="black")  # we can pass arguments to .coastlines function
ax2.set_title('r(DJF SOI,DJF 700mb GPH) FDR', fontsize=12)
cb2 = plt.colorbar(fx2,  orientation='vertical',location='left',shrink=0.9,pad=0.05,ticks=[-1, -0.75, -0.50, -0.25, 0.0, 0.25, 0.50, 0.75, 1])
ax2.scatter(lons[sig_area2], lats[sig_area2], marker = '.', s = 0.1, c = 'k', alpha = 0.4, transform = ccrs.PlateCarree())
cb2.set_label('Correlation', fontsize=12)

# %% [markdown]
# One of the main subjects of the lectures that accompany this notebook is the issue of avoiding Type I and Type II errors.  There is no single approach that will optimize the trade off between these two errors, and as always my reminder to you is to be thoughtful and thorough in your approach to significance testing, the interpretation of meaningful relationships (or not) in your data, and mindful that the ultimate goal is to make robust and reasonable inferences and interpretations of the system (be it social or physical or both) of interest.  In a paper titled, _[To Bonferroni or not to Bonferroni: when and how are the questions](https://www.jstor.org/stable/20168454)_ in 2000, Cabin and Mitchell explored the issue of how to deal with multiple tests of significance and the potential for bias (emphasis mine):
#
# > Although overzealous use of Bonferroni corrections needlessly increases Type II error rates (i.e., accepting the null hypothesis when it is actually false), failing to use these corrections when needed inflates Type I error rates. **Both errors are important**, and slavish attention to one or the other will compromise the integrity of many statistical procedures. Unfortunately, the line between overzealousness and laxity is, in most cases, neither clear nor generally agreed upon. Determining what constitutes an appropriate grouping of statistical tests requires careful consideration of the way the statistics relate to the data and hypotheses of interest, and there are many situations in which reasonable and well-intentioned researchers may disagree about how to make these groupings and apply appropriate corrections
#
#
#
# > Finally, authors, referees, and readers should strive to avoid blind adherence to particular P values; effect sizes, biological significance, and common sense ultimately may be the most important criteria for interpreting the results of all statistical tests
